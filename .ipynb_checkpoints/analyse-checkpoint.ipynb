# %%
print("h  e z    z  l    l       o")
# Out:
# h  e z    z  l    l       o

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

labels = pd.read_csv("alt_acsincome_ca_labels_85.csv")
features = pd.read_csv("alt_acsincome_ca_features_85.csv")

df = pd.concat([labels, features], axis=1)
df["PINCP"] = df["PINCP"].map({True: 1, False: 0})

prob_by_sex = df.groupby("SEX")["PINCP"].mean()
sex = np.arange(1, 3)

prob_by_age = df.groupby("AGEP")["PINCP"].mean()
ages = np.arange(0, 100)

plt.figure(figsize=(12, 6))
sns.lineplot(x=ages, y=prob_by_age.reindex(ages, fill_value=0))
plt.title("Probability of 50k + Income by Age")
plt.xlabel("Age")
plt.ylabel("Probability of Income")
plt.grid()
plt.show()

plt.figure(figsize=(8, 6))
sns.barplot(x=sex, y=prob_by_sex.reindex(sex, fill_value=0))
plt.title("Probability of 50k + Income by Sex")
plt.xticks(ticks=[0, 1], labels=["Male", "Female"])
plt.xlabel("Sex")
plt.ylabel("Probability of Income")
plt.grid()
plt.show()

numeric_cols = ["PINCP", "AGEP", "WKHP", "SCHL", "SEX"]

plt.figure(figsize=(8, 6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Selected Numeric Variables")
plt.show()

# %%
X = features
y = labels["PINCP"].map({True: 1, False: 0})



features_encoded = pd.get_dummies(features,prefix=['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'], columns = ['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'], drop_first=True, dtype=int)

features_encoded.to_csv('alt_acqsincome_ca_features_one_hot_encoded.csv', index=False)
print("finished")
# Out:
# finished

# %% [markdown]
# | expérimentation1 | train | test |
# |------------------|-------|------|
# | Taille jeu de données         | (133052, 808) | (33263, 808)|

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features_encoded, y, test_size=0.2, random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (133052, 808)
# (33263, 808)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import time

def plot_confusion_matrix(y_true, y_pred, model_name, dataset="Test"):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5,4))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        annot_kws={"color": "black"},
        xticklabels=["Pred 0", "Pred 1"],
        yticklabels=["True 0", "True 1"]
    )
    plt.title(f"{model_name} - {dataset} Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()




def evaluate_model(model, model_name):
    print(f"\n===== {model_name} =====")

    # ---- TRAIN ----
    import time
    start = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - start

    # ---- PREDICT ----
    y_train_pred = model.predict(X_train)
    y_test_pred  = model.predict(X_test)

    # ---- METRICS ----
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc  = accuracy_score(y_test, y_test_pred)

    # ---- PRINT SUMMARY ----
    print(f"Train accuracy: {train_acc:.4f}")
    print(f"Test accuracy:  {test_acc:.4f}")
    print(f"Train time:     {train_time:.2f} sec")

    # ---- TEXT CONFUSION MATRICES ----
    cm_test = confusion_matrix(y_test, y_test_pred)
    cm_train = confusion_matrix(y_train, y_train_pred)

    print("\nConfusion Matrix (Test):")
    print(cm_test)

    print("\nConfusion Matrix (Train):")
    print(cm_train)

    # ---- GRAPHICAL CONFUSION MATRICES ----
    plot_confusion_matrix(y_test, y_test_pred, model_name, dataset="Test")
    plot_confusion_matrix(y_train, y_train_pred, model_name, dataset="Train")

    # ---- RETURN ----
    return {
        "model": model_name,
        "train_acc": train_acc,
        "test_acc": test_acc,
        "train_time": train_time,
        "cm_train": cm_train,
        "cm_test": cm_test
    }


models = [
    (RandomForestClassifier(random_state=42), "Random Forest"),
    (AdaBoostClassifier(random_state=42), "AdaBoost"),
    (GradientBoostingClassifier(random_state=42), "Gradient Boosting")
]

results = {}

for model, name in models:
    results[name] = evaluate_model(model, name)
# Out:
# ===== Random Forest =====
# Train accuracy: 0.9981
# Test accuracy:  0.8142
# Train time:     79.74 sec
#
# Confusion Matrix (Test):
# [[16689  2905]
#  [ 3276 10393]]
#
# Confusion Matrix (Train):
# [[78387   131]
#  [  120 54414]]
# ===== AdaBoost =====
# Train accuracy: 0.7781
# Test accuracy:  0.7771
# Train time:     22.74 sec
#
# Confusion Matrix (Test):
# [[16295  3299]
#  [ 4116  9553]]
#
# Confusion Matrix (Train):
# [[65273 13245]
#  [16285 38249]]
# ===== Gradient Boosting =====
# Train accuracy: 0.7995
# Test accuracy:  0.7986
# Train time:     86.24 sec
#
# Confusion Matrix (Test):
# [[16547  3047]
#  [ 3652 10017]]
#
# Confusion Matrix (Train):
# [[66311 12207]
#  [14470 40064]]

# %% [markdown]
# | Résultats en entraînement  | Random Forest                    | AdaBoost                            | XGBoost/Gradient Boosting           |
# | -------------------------- | -------------------------------- | ----------------------------------- | ----------------------------------- |
# | **Accuracy**               | 0.9981                           | 0.7781                              | 0.7995                              |
# | **Temps de calcul (sec.)** | 78.64 s                          | 24.18 s                             | 92.94 s                             |
# | **Matrice de confusion**   | [[78387, 131],<br> [120, 54414]] | [[65679, 12839],<br>[13947, 40587]] | [[66311, 12207],<br>[14470, 40064]] |

# %% [markdown]
# | Résultats en test          | Random Forest                     | AdaBoost                          | XGBoost/Gradient Boosting         |
# | -------------------------- | --------------------------------- | --------------------------------- | --------------------------------- |
# | **Accuracy**               | 0.8142                            | 0.7771                            | 0.7986                            |
# | **Matrice de confusion**   | [[16689, 2905],<br>[3276, 10393]] | [[16357, 3237],<br>[3514, 10155]] | [[16547, 3047],<br>[3652, 10017]] |

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
print("aaazaz")
# Out:
# aaazaz

# %%
param_grid_rf = {
    "n_estimators": [200, 400],
    "max_depth": [10, 20, None],
    "min_samples_split": [2, 10],
    "max_features": ["sqrt", "log2"]
}

# %%
param_grid_gb = {
    "n_estimators": [100, 200, 500],
        "learning_rate": [0.05, 0.1],
    "max_depth": [1, 3, 6]
}

# %%
param_grid_ada = {
    "n_estimators": [50, 100, 300],
    "learning_rate": [0.1, 0.2, 0.5]
}
print("test")
# Out:
# tes t

# %%
grid_rf = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42, n_jobs=-1),
    param_grid=param_grid_rf,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1
)

grid_rf.fit(X_train, y_train)
best_rf = grid_rf.best_estimator_

print("Best Random Forest params:", grid_rf.best_params_)
results_rf_opt = evaluate_model(best_rf, "Random Forest (Optimisé)")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# /home/amri/.local/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Random Forest params: {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 400}
#
# ===== Random Forest (Optimisé) =====
# Train accuracy: 0.9374
# Test accuracy:  0.8236
# Train time:     64.82 sec
#
# Confusion Matrix (Test):
# [[16925  2669]
#  [ 3198 10471]]
#
# Confusion Matrix (Train):
# [[74886  3632]
#  [ 4699 49835]]

# %%
grid_ada = GridSearchCV(
    estimator=AdaBoostClassifier(random_state=42),
    param_grid=param_grid_ada,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1
)



grid_ada.fit(X_train, y_train)
best_ada = grid_ada.best_estimator_

print("Best AdaBoost params:", grid_ada.best_params_)
results_ada_opt = evaluate_model(best_ada, "AdaBoost (Optimisé)")
print("results:     ", results_ada_opt)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best AdaBoost params: {'learning_rate': 0.5, 'n_estimators': 300}
#
# ===== AdaBoost (Optimisé) =====
# Train accuracy: 0.7852
# Test accuracy:  0.7853
# Train time:     137.06 sec
#
# Confusion Matrix (Test):
# [[16518  3076]
#  [ 4065  9604]]
#
# Confusion Matrix (Train):
# [[66141 12377]
#  [16205 38329]]
# results:      {'model': 'AdaBoost (Optimisé)', 'train_acc': 0.7851817334575956, 'test_acc': 0.7853170189098999, 'train_time': 137.05942344665527, 'cm_train': array([[66141, 12377],
#        [16205, 38329]]), 'cm_test': array([[16518,  3076],
#        [ 4065,  9604]])}
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Gradient Boosting params: {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 200}
#
# ===== Gradient Boosting (Optimisé) =====
# Train accuracy: 0.8316
# Test accuracy:  0.8201
# Train time:     163.89 sec
#
# Confusion Matrix (Test):
# [[16608  2986]
#  [ 2998 10671]]
#
# ...

# %%
grid_gb = GridSearchCV(
    estimator=GradientBoostingClassifier(random_state=42),
    param_grid=param_grid_gb,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1
)

grid_gb.fit(X_train, y_train)
best_gb = grid_gb.best_estimator_

print("Best Gradient Boosting params:", grid_gb.best_params_)
results_gb_opt  = evaluate_model(best_gb, "Gradient Boosting (Optimisé)")
print("results:    ", results_gb_opt)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits

# %%
import pandas as pd
import matplotlib.pyplot as plt

train_data = {
    "Model": ["Random Forest", "AdaBoost", "XGBoost"],
    "Default": [0.9981, 0.7781, 0.7995],
    "Optimized": [0.9374, 0.7852, 0.8316]
}

df_train = pd.DataFrame(train_data)

df_train.set_index("Model").plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Training Accuracy: Default vs Optimized Models")
plt.ylabel("Accuracy")
plt.ylim(0.75, 1.0)
plt.grid(axis="y")
plt.xticks(rotation=0)
plt.show()

# %%
test_data = {
    "Model": ["Random Forest", "AdaBoost", "XGBoost"],
    "Default": [0.8130, 0.7771, 0.7986],
    "Optimized": [0.8206, 0.7853, 0.8216]
}

df_test = pd.DataFrame(test_data)

df_test.set_index("Model").plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Test Accuracy: Default vs Optimized Models")
plt.ylabel("Accuracy")
plt.ylim(0.75, 0.85)
plt.grid(axis="y")
plt.xticks(rotation=0)
plt.show()

# %%
# Chargement nouveau dataset (ex: autre État)
labels_colorado = pd.read_csv("Complementary data/acsincome_co_label.csv")
features_colorado = pd.read_csv("Complementary data/acsincome_co_allfeatures.csv")

labels_colorado["PINCP"].value_counts(dropna=False)
# Out:
# PINCP
# 0    18334
# 1    12972
# Name: count, dtype: int64

# %%
# Labels: already binary → NO mapping
y_co = labels_colorado["PINCP"].astype(int)

# One-hot encoding (same columns as CA)
features_co_encoded = pd.get_dummies(
    features_colorado,
    prefix=['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'],
    columns=['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'],
    drop_first=True,
    dtype=int
)

# Align columns with training set
features_co_encoded = features_co_encoded.reindex(
    columns=features_encoded.columns,
    fill_value=0
)

# (Optional) save
features_co_encoded.to_csv(
    "acsincome_co_features_one_hot_encoded.csv",
    index=False
)

print("Colorado preprocessing finished")
# Out:
# Colorado preprocessing finished

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

models_optimized = {
    "Random Forest (Optimisé)": best_rf,
    "AdaBoost (Optimisé)": best_ada,
    "XGBoost (Optimisé)": best_gb
}

results_colorado = {}

for name, model in models_optimized.items():
    print(f"\n===== {name} — Colorado =====")
    
    y_pred = model.predict(features_co_encoded)
    
    acc = accuracy_score(y_co, y_pred)
    cm = confusion_matrix(y_co, y_pred)
    
    results_colorado[name] = {
        "accuracy": acc,
        "confusion_matrix": cm
    }
    
    print("Accuracy:", acc)
    print("Confusion Matrix:")
    print(cm)
# Out:
# ===== Random Forest (Optimisé) — Colorado =====
# Accuracy: 0.785759918226538
# Confusion Matrix:
# [[13660  4674]
#  [ 2033 10939]]
#
# ===== AdaBoost (Optimisé) — Colorado =====
# Accuracy: 0.7629527886028238
# Confusion Matrix:
# [[13833  4501]
#  [ 2920 10052]]
#
# ===== XGBoost (Optimisé) — Colorado =====
# Accuracy: 0.7839072382290935
# Confusion Matrix:
# [[13470  4864]
#  [ 1901 11071]]

# %%
# Chargement nouveau dataset (ex: autre État)
labels_nevada = pd.read_csv("Complementary data/acsincome_ne_label.csv")
features_nevada = pd.read_csv("Complementary data/acsincome_ne_allfeatures.csv")

labels_nevada["PINCP"].value_counts(dropna=False)
# Out:
# axsdsaaa
# PINCP
# 0    7417
# 1    3368
# Name: count, dtype: int64

# %%
# Labels: already binary → NO mapping
y_ne = labels_nevada["PINCP"].astype(int)

# One-hot encoding (same columns as CA)
features_ne_encoded = pd.get_dummies(
    features_nevada,
    prefix=['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'],
    columns=['COW','SCHL','MAR','OCCP','POBP','RELP','SEX','RAC1P'],
    drop_first=True,
    dtype=int
)

# Align columns with training set
features_ne_encoded = features_ne_encoded.reindex(
    columns=features_encoded.columns,
    fill_value=0
)

features_ne_encoded.to_csv(
    "acsincome_ne_features_one_hot_encoded.csv",
    index=False
)

print("Nevada preprocessing finished")
# Out:
# Nevada preprocessing finished

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

models_optimized = {
    "Random Forest (Optimisé)": best_rf,
    "AdaBoost (Optimisé)": best_ada,
    "XGBoost (Optimisé)": best_gb
}

results_nevada = {}

for name, model in models_optimized.items():
    print(f"\n===== {name} — Nevada =====")
    
    y_pred = model.predict(features_ne_encoded)
    
    acc = accuracy_score(y_ne, y_pred)
    cm = confusion_matrix(y_ne, y_pred)
    
    results_nevada[name] = {
        "accuracy": acc,
        "confusion_matrix": cm
    }
    
    print("Accuracy:", acc)
    print("Confusion Matrix:")
    print(cm)
# Out:
# ===== Random Forest (Optimisé) — Nevada =====
# Accuracy: 0.7553082985628188
# Confusion Matrix:
# [[5361 2056]
#  [ 583 2785]]
#
# ===== AdaBoost (Optimisé) — Nevada =====
# Accuracy: 0.7313861845155308
# Confusion Matrix:
# [[5274 2143]
#  [ 754 2614]]
#
# ===== XGBoost (Optimisé) — Nevada =====
# Accuracy: 0.7419564209550301
# Confusion Matrix:
# [[5180 2237]
#  [ 546 2822]]

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_states = {
    "State": ["RF", "ADA", "GB"],
    "California": [0.8206, 0.7853, 0.8216],
    "Colorado": [0.7839, 0.7630, 0.7856],
    "Nevada": [0.7553, 0.7314, 0.7420]
}

df_states = pd.DataFrame(data_states).set_index("State")

df_states.plot(
    kind="bar",
    figsize=(9,5)
)

plt.ylabel("Accuracy")
plt.ylim(0.70, 0.85)
plt.grid(axis="y")
plt.xticks(rotation=0)
plt.show()

# %%
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import time
import pandas as pd

models = {
    "Random Forest": RandomForestClassifier(
        n_estimators=400,
        max_depth=None,
        max_features="log2",
        min_samples_split=10,
        random_state=42,
        n_jobs=-1
    ),
    "AdaBoost": AdaBoostClassifier(
        n_estimators=300,
        learning_rate=0.5,
        random_state=42
    ),
    "XGBoost": GradientBoostingClassifier(
        n_estimators=500,
        learning_rate=0.1,
        max_depth=6,
        random_state=42
    )
}

train_sizes = [0.1, 0.25, 0.5, 0.75, 1.0]

results_exp5 = []

for model_name, model in models.items():
    print(f"\n===== {model_name} =====")
    
    for size in train_sizes:
        print(f"Training with {int(size*100)}% of training data")

        # Subsample training data
        X_sub, y_sub = resample(
            X_train,
            y_train,
            n_samples=int(size * len(X_train)),
            random_state=42
        )

        start = time.time()
        model.fit(X_sub, y_sub)
        train_time = time.time() - start

        y_pred = model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)

        results_exp5.append({
            "Model": model_name,
            "Train size (%)": int(size * 100),
            "Accuracy (test)": acc,
            "Training time (s)": train_time
        })

df_exp5 = pd.DataFrame(results_exp5)
print(df_exp5)
# Out:
# ===== Random Forest =====
# Training with 10% of training data
# Training with 25% of training data
# Training with 50% of training data
# Training with 75% of training data
# Training with 100% of training data
#
# ===== AdaBoost =====
# Training with 10% of training data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 48
#      40 X_sub, y_sub = resample(
#      41     X_train,
#      42     y_train,
#      43     n_samples=int(size * len(X_train)),
#      44     random_state=42
#      45 )
#      47 start = time.time()
# ---> 48 model.fit(X_sub, y_sub)
#      49 train_time = time.time() - start
#      51 y_pred = model.predict(X_test)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
# ...

# %%
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import time
import pandas as pd

models = {
    "XGBoost": GradientBoostingClassifier(
        n_estimators=500,
        learning_rate=0.1,
        max_depth=6,
        random_state=42
    )
}

train_sizes = [0.1, 0.25, 0.5, 0.75, 1.0]

results_exp5 = []

for model_name, model in models.items():
    print(f"\n===== {model_name} =====")
    
    for size in train_sizes:
        print(f"Training with {int(size*100)}% of training data")

        # Subsample training data
        X_sub, y_sub = resample(
            X_train,
            y_train,
            n_samples=int(size * len(X_train)),
            random_state=42
        )

        start = time.time()
        model.fit(X_sub, y_sub)
        train_time = time.time() - start

        y_pred = model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)

        results_exp5.append({
            "Model": model_name,
            "Train size (%)": int(size * 100),
            "Accuracy (test)": acc,
            "Training time (s)": train_time
        })

df_exp5 = pd.DataFrame(results_exp5)
print(df_exp5)
# Out:
# ===== XGBoost =====
# Training with 10% of training data
# Training with 25% of training data
# Training with 50% of training data
# Training with 75% of training data
# Training with 100% of training data
#      Model  Train size (%)  Accuracy (test)  Training time (s)
# 0  XGBoost              10         0.809879          58.487230
# 1  XGBoost              25         0.815140         157.948028
# 2  XGBoost              50         0.819710         315.992195
# 3  XGBoost              75         0.820702         500.989665
# 4  XGBoost             100         0.821123         675.066923

# %%
import matplotlib.pyplot as plt

# Training sizes
train_sizes = [10, 25, 50, 75, 100]

# Accuracies from your results
rf_acc = [0.809638, 0.814899, 0.816703, 0.817906, 0.818687]
ada_acc = [0.779334, 0.785678, 0.784205, 0.783934, 0.783393]
xgb_acc = [0.809879, 0.815140, 0.819710, 0.820702, 0.821123]

plt.figure(figsize=(8,5))

plt.plot(train_sizes, rf_acc, marker="o", label="Random Forest")
plt.plot(train_sizes, ada_acc, marker="o", label="AdaBoost")
plt.plot(train_sizes, xgb_acc, marker="o", label="XGBoost")

plt.xlabel("Training set size (%)")
plt.ylabel("Test Accuracy")
plt.title("Impact of Training Set Size on Test Accuracy (Optimized Models)")
plt.ylim(0.77, 0.83)
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.inspection import permutation_importance
print("import finished")
# Out:
# import finished

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Initialize XGBoost (GradientBoostingClassifier)
best_xgb = GradientBoostingClassifier(
    n_estimators=500,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

# Train the XGBoost model
best_xgb.fit(X_train, y_train)

print("XGBoost model trained")

from sklearn.inspection import permutation_importance

# Subsample test set
X_test_small = X_test.sample(n=2000, random_state=42)
y_test_small = y_test.loc[X_test_small.index]
# Out:
# XGBoost model trained

# %%
from sklearn.inspection import permutation_importance

# Ensure you are selecting the correct y_test values corresponding to the smaller subset of X_test
y_test_small = y_test.loc[X_test_small.index]

print("Starting lightweight permutation importance...")

# Permutation importance for the XGBoost model
perm = permutation_importance(
    best_xgb,             # Ensure best_xgb is already trained
    X_test_small,         # Use the subset of X_test
    y_test_small,         # Use the corresponding subset of y_test
    n_repeats=2,          # Perform only a few repeats for speed (you can adjust this)
    random_state=42,
    scoring="accuracy",   # Use accuracy to measure the importance
    n_jobs=1              # Limit to one job to avoid parallel processing (you can increase it for faster execution)
)

# Create DataFrame to hold the permutation importance values
importances_perm = pd.DataFrame({
    "feature": X_test_small.columns,
    "importance_mean": perm.importances_mean,
    "importance_std": perm.importances_std
}).sort_values("importance_mean", ascending=False)

# Show top 15 features by importance
importances_perm.head(15)
# Out:
# Starting lightweight permutation importance...
#          feature  importance_mean  importance_std
# 1           WKHP          0.07950         0.00300
# 0           AGEP          0.04425         0.00125
# 29     SCHL_22.0          0.01875         0.00175
# 28     SCHL_21.0          0.01425         0.00275
# 233  OCCP_3255.0          0.00925         0.00075
# 798    RELP_17.0          0.00575         0.00125
# 258  OCCP_3602.0          0.00400         0.00100
# 31     SCHL_24.0          0.00325         0.00125
# 124  OCCP_1530.0          0.00325         0.00125
# 6        COW_6.0          0.00275         0.00125
# 799      SEX_2.0          0.00250         0.00050
# 97   OCCP_1021.0          0.00250         0.00100
# 295  OCCP_4110.0          0.00225         0.00125
# 303  OCCP_4220.0          0.00225         0.00025
# 783     RELP_2.0          0.00225         0.00025

# %%
import matplotlib.pyplot as plt

# Adjust the feature names for clarity (e.g., grouping one-hot encoded features)
importances_perm['feature'] = importances_perm['feature'].str.split('_').str[0]  # Simplifying feature names

# Number of top features to display
top_k = 10

# Select top features and reverse order for horizontal bar plot
top_features = importances_perm.head(top_k).iloc[::-1]

# Plot permutation importance
plt.figure(figsize=(10,6))
plt.barh(
    top_features["feature"],
    top_features["importance_mean"]
)

plt.xlabel("Decrease in accuracy after permutation")
plt.title("Permutation Feature Importance (Top 10) - XGBoost")
plt.grid(axis="x")
plt.tight_layout()
plt.show()

# %%
# LIME for XGBoost

from lime.lime_tabular import LimeTabularExplainer
import numpy as np

# Convert to numpy
X_train_np = X_train.values
X_test_np = X_test.values

# Feature names for LIME
feature_names = X_train.columns.tolist()
class_names = ["<=50k", ">50k"]

# Initialize LIME Explainer
explainer = LimeTabularExplainer(
    training_data=X_train_np,
    feature_names=feature_names,
    class_names=class_names,
    mode="classification",
    discretize_continuous=True
)

print("LIME Initialized for XGBoost")
# Out:
# LIME Initialized for XGBoost

# %%
# Choose some test samples
example_ids = [0, 1]

for idx in example_ids:
    exp = explainer.explain_instance(
        X_test_np[idx],
        best_xgb.predict_proba,
        num_features=10
    )
    
    print(f"\nLIME explanation for test sample {idx}")
    print("True label:", y_test.iloc[idx])
    
    # Plot the explanation
    fig = exp.as_pyplot_figure()
    plt.show()
# Out:
# /home/amri/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# LIME explanation for test sample 0
# True label: 1
# /home/amri/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# LIME explanation for test sample 1
# True label: 1

# %%
print("SHAP now")
# Out:
# SHAP now

# %%
import shap
import matplotlib.pyplot as plt

# Sous-échantillon pour éviter les crashes
X_shap = X_test.sample(n=2000, random_state=42)

# Prédictions
y_pred = best_xgb.predict(X_shap)

# SHAP explainer
explainer = shap.TreeExplainer(best_xgb)
shap_values = explainer.shap_values(
    X_shap,
    check_additivity=False
)

# Séparation par classe prédite
X_0 = X_shap[y_pred == 0]
X_1 = X_shap[y_pred == 1]

shap_0 = shap_values[y_pred == 0]
shap_1 = shap_values[y_pred == 1]

# ===== PLOTS VERTICAUX =====
fig, axes = plt.subplots(2, 1, figsize=(10, 10))

# Classe 0 (≤50k)
plt.sca(axes[0])
shap.summary_plot(
    shap_0,
    X_0,
    show=False,
    max_display=10
)
axes[0].set_title("Classe ≤ 50k")

# Classe 1 (>50k)
plt.sca(axes[1])
shap.summary_plot(
    shap_1,
    X_1,
    show=False,
    max_display=10
)
axes[1].set_title("Classe > 50k")

plt.tight_layout()
plt.show()

# %%
import shap
import matplotlib.pyplot as plt

# Sous-échantillon pour éviter crash
X_shap = X_test.sample(n=2000, random_state=42)

# SHAP explainer
explainer = shap.TreeExplainer(best_xgb)

# SHAP values
shap_values = explainer.shap_values(
    X_shap,
    check_additivity=False
)

# Classe positive (>50k)
plt.figure(figsize=(10,6))
shap.summary_plot(
    shap_values,
    X_shap,
    max_display=15,
    show=True
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import shap

# Prédictions
y_pred = best_xgb.predict(X_test)

groups = {
    "True Positives (TP)": X_test[(y_test == 1) & (y_pred == 1)],
    "True Negatives (TN)": X_test[(y_test == 0) & (y_pred == 0)],
    "False Positives (FP)": X_test[(y_test == 0) & (y_pred == 1)],
    "False Negatives (FN)": X_test[(y_test == 1) & (y_pred == 0)],
}

explainer = shap.TreeExplainer(best_xgb)

for name, X_group in groups.items():
    if len(X_group) < 50:
        continue  # éviter bruit / crash

    X_group_small = X_group.sample(
        n=min(1000, len(X_group)),
        random_state=42
    )

    shap_vals = explainer.shap_values(
        X_group_small,
        check_additivity=False
    )

    plt.figure(figsize=(9,5))
    shap.summary_plot(
        shap_vals,
        X_group_small,
        show=False,
        max_display=10
    )
    plt.title(name)
    plt.tight_layout()
    plt.show()

# %%
# Counterfactual Analysis for XGBoost

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Choose a test sample
idx = 0
x_base = X_test.iloc[idx].copy()

# Parameters to analyze
params = {
    "WKHP": np.arange(x_base["WKHP"], x_base["WKHP"] + 41, 5),
    "AGEP": np.arange(x_base["AGEP"], x_base["AGEP"] + 21, 2),
}

# If WAGP is present, include it
if "WAGP" in X_test.columns:
    params["WAGP"] = np.linspace(
        max(0, x_base["WAGP"] - 20000),
        x_base["WAGP"] + 20000,
        8
    )

# For one-hot variables (binary)
for col in ["COW_1", "SEX_1"]:
    if col in X_test.columns:
        params[col] = [0, 1]

# Plot
plt.figure(figsize=(9, 6))

for feature, values in params.items():
    probs = []

    for v in values:
        x_cf = x_base.copy()
        x_cf[feature] = v
        prob = best_xgb.predict_proba(pd.DataFrame([x_cf]))[0, 1]
        probs.append(prob)

    plt.plot(values, probs, marker="o", label=feature)

# Decision threshold line
plt.axhline(0.5, color="red", linestyle="--", label="Decision threshold (0.5)")

plt.xlabel("Parameter Value")
plt.ylabel("Predicted Probability (>50k)")
plt.title("Counterfactual Multivariate Analysis (1 individual) - XGBoost")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 39
#      37     x_cf = x_base.copy()
#      38     x_cf[feature] = v
# ---> 39     prob = best_xgb.predict_proba(pd.DataFrame([x_cf]))[0, 1]
#      40     probs.append(prob)
#      42 plt.plot(values, probs, marker="o", label=feature)
#
# NameError: name 'best_xgb' is not defined
